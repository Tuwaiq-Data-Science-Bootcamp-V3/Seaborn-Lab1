# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.shape
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   sex       891 non-null    object
#  2   fare      891 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.0+ KB
#      survived     sex     fare
# 0           0    male   7.2500
# 1           1  female  71.2833
# 2           1  female   7.9250
# 3           1  female  53.1000
# 4           0    male   8.0500
# ..        ...     ...      ...
# 886         0    male  13.0000
# 887         1  female  30.0000
# 888         0  female  23.4500
# 889         1    male  30.0000
# 890         0    male   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Data Description
#
# - Survival : 0 = No, 1 = Yes
# - pclass(Ticket Class) : 1 = 1st, 2 = 2nd, 3 = 3rd
# - Sex(Gender) : Male, Female
# - Age : Age in years
# - SibSp : Number of siblings/spouses abroad the titanic
# - Parch : Number of parents/children abrod the titanic
# - Ticket : Ticket Number
# - Fare : Passenger fare
# - Cabin : Cabin Number
# - Embarked : Port of Embarkation, C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # Q1: Print first and last rows from the dataset

# %%
#Here to print first and last row using pandas
print(df.head(1))
print('---------------------------------------------------------------------')
print(df.tail(1))
df
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# ---------------------------------------------------------------------
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 890         0       3  male  32.0      0      0  7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 890        True  NaN  Queenstown    no   True
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # Q2: Select only survived people

# %%
Su = df[df['survived'] == 1]
Su
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone         new_column
# 1    woman       False    C    Cherbourg   yes  False     FirstCherbourg
# 2    woman       False  NaN  Southampton   yes   True   ThirdSouthampton
# 3    woman       False    C  Southampton   yes  False   FirstSouthampton
# 8    woman       False  NaN  Southampton   yes  False   ThirdSouthampton
# 9    child       False  NaN    Cherbourg   yes  False    SecondCherbourg
# ..     ...         ...  ...          ...   ...    ...                ...
# 875  child       False  NaN    Cherbourg   yes   True     ThirdCherbourg
# 879  woman       False    C    Cherbourg   yes  False     FirstCherbourg
# 880  woman       False  NaN  Southampton   yes  False  SecondSouthampton
# 887  woman       False    B  Southampton   yes   True   FirstSouthampton
# 889    man        True    C    Cherbourg   yes   True     FirstCherbourg
#
# [342 rows x 16 columns]

# %% [markdown]
# # Q3: Select sex, fare, survived columns

# %%
df1 = pd.read_csv("titanic.csv", usecols=['sex','fare','survived'])
df1
# Out:
#      survived     sex     fare
# 0           0    male   7.2500
# 1           1  female  71.2833
# 2           1  female   7.9250
# 3           1  female  53.1000
# 4           0    male   8.0500
# ..        ...     ...      ...
# 886         0    male  13.0000
# 887         1  female  30.0000
# 888         0  female  23.4500
# 889         1    male  30.0000
# 890         0    male   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# # Q4: Add a new_column to a DataFrame that combines class and embark_town

# %%
df['new_column'] = df['class'].astype(object) + df['embark_town'].astype(object)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone         new_column
# 0      man        True  NaN  Southampton    no  False   ThirdSouthampton
# 1    woman       False    C    Cherbourg   yes  False     FirstCherbourg
# 2    woman       False  NaN  Southampton   yes   True   ThirdSouthampton
# 3    woman       False    C  Southampton   yes  False   FirstSouthampton
# 4      man        True  NaN  Southampton    no   True   ThirdSouthampton
# ..     ...         ...  ...          ...   ...    ...                ...
# 886    man        True  NaN  Southampton    no   True  SecondSouthampton
# 887  woman       False    B  Southampton   yes   True   FirstSouthampton
# 888  woman       False  NaN  Southampton    no  False   ThirdSouthampton
# 889    man        True    C    Cherbourg   yes   True     FirstCherbourg
# 890    man        True  NaN   Queenstown    no   True    ThirdQueenstown
#
# [891 rows x 16 columns]

# %% [markdown]
# # Q5: Remove new_column from the DataFrame

# %%
NewDf = df.drop('new_column', axis=1)
NewDf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # Q6: Filter DataFrame for rows of survived Males only

# %%
MaleDf = Su[Su['sex'] == 'male']
MaleDf
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone         new_column
# 17     man        True  NaN  Southampton   yes   True  SecondSouthampton
# 21     man        True    D  Southampton   yes   True  SecondSouthampton
# 23     man        True    A  Southampton   yes   True   FirstSouthampton
# 36     man        True  NaN    Cherbourg   yes   True     ThirdCherbourg
# 55     man        True    C  Southampton   yes   True   FirstSouthampton
# ..     ...         ...  ...          ...   ...    ...                ...
# 838    man        True  NaN  Southampton   yes   True   ThirdSouthampton
# 839    man        True    C    Cherbourg   yes   True     FirstCherbourg
# 857    man        True    E  Southampton   yes   True   FirstSouthampton
# 869  child       False  NaN  Southampton   yes  False   ThirdSouthampton
# 889    man        True    C    Cherbourg   yes   True     FirstCherbourg
#
# [109 rows x 16 columns]

# %%
# Out:
#       age   class
# 17    NaN  Second
# 21   34.0  Second
# 23   28.0   First
# 36    NaN   Third
# 55    NaN   First
# ..    ...     ...
# 838  32.0   Third
# 839   NaN   First
# 857  51.0   First
# 869   4.0   Third
# 889  26.0   First
#
# [109 rows x 2 columns]

# %% [markdown]
# # Q7: The total number of males who survived

# %%
print(MaleDf['survived'].count())
# Out:
# 109

# %% [markdown]
# # Q8: How many values in each class?

# %%
FirstClass = df[df['class'] == 'First'].count()
SecondClass = df[df['class'] == 'Second'].count()
ThirdClass = df[df['class'] == 'Third'].count()

print('First = ',FirstClass['class'])
print('Second = ',SecondClass['class'])
print('Third = ',ThirdClass['class'])
# Out:
# First =  216
# Second =  184
# Third =  491

# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns
sns.set()

# %% [markdown]
# # Q9: Draw barplot represents survived people based on sex

# %%
sns.barplot(x='sex', y='survived',data=df);

# %% [markdown]
# # Q10: Draw catplot represents survived people based on embarked

# %%
EmbarkedData_S = df[df['embarked'] == 'S']
EmbarkedData_C = df[df['embarked'] == 'C']
EmbarkedData_Q = df[df['embarked'] == 'Q']

sns.countplot(x='survived', data=EmbarkedData_S);
sns.countplot(x='survived', data=EmbarkedData_C);
sns.countplot(x='survived', data=EmbarkedData_Q);

# %% [markdown]
# # Q11: Draw boxplot represents distribution of male and female based on age and pclass

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="sex", y="age", data=df,hue='pclass', palette='rainbow');

# %% [markdown]
# # Q12: Draw heatmap represents correlations between sibsp, parch, age, fare, and survived columns

# %%
NewCol = pd.read_csv("titanic.csv", usecols=['sibsp','parch','age','fare','survived'])
corr_matrix = NewCol.corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q13: Draw factorplot represents the relation between sibsp and survived columns

# %%
sns.factorplot(x='sibsp', y='survived', data=df)
# Out:
# C:\Users\H P\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Q14: Draw extra insights [Optional]

# %%
sns.relplot(
    x="age", 
    y="fare", 
    hue="survived",
    size="class",
    alpha=.1, 
    palette="muted",
    height=6, 
    data=df
)
